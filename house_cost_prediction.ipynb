# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("house.csv")
data.head()
# Out:
#    House_Size (sqft)  Num_Bedrooms  Num_Bathrooms  Num_Floors  Year_Built  \
# 0               1660             1              2           3        2003
# 1               4572             3              2           3        1950
# 2               3892             4              3           3        1993
# 3               1266             2              1           1        1994
# 4               4244             4              2           1        1996
#
#    Location_Score  Nearby_Schools (count)  Crime_Rate (per 1000 people)  \
# 0               9                       4                          9.50
# 1               4                       1                          3.70
# 2              10                       5                          7.39
# 3               2                       2                          5.62
# 4               3                       7                          1.08
#
#    Distance_to_City_Center (miles)  House_Price ($)
# 0                            46.69         370810.0
# 1                            22.24         648460.0
# 2                            49.03         749600.0
# 3                            25.86         167180.0
# 4                             6.16         721200.0

# %%
corelation=data.corr()
print(corelation)
# Out:
#                                  House_Size (sqft)  Num_Bedrooms  \
# House_Size (sqft)                         1.000000     -0.010507
# Num_Bedrooms                             -0.010507      1.000000
# Num_Bathrooms                            -0.012448      0.041491
# Num_Floors                                0.046737     -0.012905
# Year_Built                                0.041368      0.038812
# Location_Score                            0.008995     -0.012595
# Nearby_Schools (count)                    0.010705      0.023048
# Crime_Rate (per 1000 people)              0.045773      0.006590
# Distance_to_City_Center (miles)           0.018404      0.029299
# House_Price ($)                           0.921747      0.068728
#
#                                  Num_Bathrooms  Num_Floors  Year_Built  \
# House_Size (sqft)                    -0.012448    0.046737    0.041368
# Num_Bedrooms                          0.041491   -0.012905    0.038812
# Num_Bathrooms                         1.000000   -0.015985   -0.025628
# Num_Floors                           -0.015985    1.000000   -0.005841
# Year_Built                           -0.025628   -0.005841    1.000000
# Location_Score                        0.023971    0.022353   -0.042686
# Nearby_Schools (count)                0.035123   -0.017044   -0.000572
# Crime_Rate (per 1000 people)         -0.016829   -0.012995   -0.079472
# Distance_to_City_Center (miles)      -0.060142    0.118003    0.035983
# House_Price ($)                       0.021083    0.066469    0.250045
#
#                                  Location_Score  Nearby_Schools (count)  \
# House_Size (sqft)                      0.008995                0.010705
# Num_Bedrooms                          -0.012595                0.023048
# Num_Bathrooms                          0.023971                0.035123
# Num_Floors                             0.022353               -0.017044
# Year_Built                            -0.042686               -0.000572
# Location_Score                         1.000000                0.007182
# Nearby_Schools (count)                 0.007182                1.000000
# Crime_Rate (per 1000 people)          -0.003050                0.010635
# Distance_to_City_Center (miles)       -0.024366                0.006542
# House_Price ($)                        0.293067                0.085782
#
#                                  Crime_Rate (per 1000 people)  \
# House_Size (sqft)                                    0.045773
# Num_Bedrooms                                         0.006590
# Num_Bathrooms                                       -0.016829
# Num_Floors                                          -0.012995
# Year_Built                                          -0.079472
# Location_Score                                      -0.003050
# Nearby_Schools (count)                               0.010635
# Crime_Rate (per 1000 people)                         1.000000
# Distance_to_City_Center (miles)                      0.056652
# House_Price ($)                                     -0.021909
#
#                                  Distance_to_City_Center (miles)  \
# House_Size (sqft)                                       0.018404
# Num_Bedrooms                                            0.029299
# Num_Bathrooms                                          -0.060142
# Num_Floors                                              0.118003
# Year_Built                                              0.035983
# Location_Score                                         -0.024366
# Nearby_Schools (count)                                  0.006542
# Crime_Rate (per 1000 people)                            0.056652
# Distance_to_City_Center (miles)                         1.000000
# House_Price ($)                                        -0.051750
#
#                                  House_Price ($)
# House_Size (sqft)                       0.921747
# Num_Bedrooms                            0.068728
# Num_Bathrooms                           0.021083
# Num_Floors                              0.066469
# Year_Built                              0.250045
# Location_Score                          0.293067
# Nearby_Schools (count)                  0.085782
# Crime_Rate (per 1000 people)           -0.021909
# Distance_to_City_Center (miles)        -0.051750
# House_Price ($)                         1.000000

# %%
import seaborn as sns
sns.heatmap(corelation, annot=True, cmap="coolwarm")
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vdata = pd.DataFrame()
vdata["Feature"] = data.columns
vdata["VIF"] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1])]
print(vdata)
# Out:
#                            Feature         VIF
# 0                House_Size (sqft)  130.838399
# 1                     Num_Bedrooms    5.895628
# 2                    Num_Bathrooms    6.885632
# 3                       Num_Floors    7.187921
# 4                       Year_Built   36.493469
# 5                   Location_Score   12.114205
# 6           Nearby_Schools (count)    3.707949
# 7     Crime_Rate (per 1000 people)    5.355654
# 8  Distance_to_City_Center (miles)    5.095581
# 9                  House_Price ($)  156.392855

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
x=data.drop(columns="House_Price ($)")
y=data["House_Price ($)"]
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2, random_state=42)
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pre=lr.predict(x_test)
mse = mean_squared_error(y_test, y_pre)
r2 = r2_score(y_test, y_pre)
print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 5.139118297581291e-19
# R² Score: 1.0

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(lr, x, y, cv=5, scoring="r2")
print(f"Cross-Validation R² Scores: {scores}")
print(f"Average R²: {scores.mean()}")
# Out:
# Cross-Validation R² Scores: [1. 1. 1. 1. 1.]
# Average R²: 1.0

# %%
data.drop(columns=["Num_Bathrooms", "Num_Floors", "Num_Bedrooms","Location_Score", "Nearby_Schools (count)"], inplace=True)

# %%
co=data.corr()
print(data.corr())
# Out:
#                                  House_Size (sqft)  Year_Built  \
# House_Size (sqft)                         1.000000    0.041368
# Year_Built                                0.041368    1.000000
# Crime_Rate (per 1000 people)              0.045773   -0.079472
# Distance_to_City_Center (miles)           0.018404    0.035983
# House_Price ($)                           0.921747    0.250045
#
#                                  Crime_Rate (per 1000 people)  \
# House_Size (sqft)                                    0.045773
# Year_Built                                          -0.079472
# Crime_Rate (per 1000 people)                         1.000000
# Distance_to_City_Center (miles)                      0.056652
# House_Price ($)                                     -0.021909
#
#                                  Distance_to_City_Center (miles)  \
# House_Size (sqft)                                       0.018404
# Year_Built                                              0.035983
# Crime_Rate (per 1000 people)                            0.056652
# Distance_to_City_Center (miles)                         1.000000
# House_Price ($)                                        -0.051750
#
#                                  House_Price ($)
# House_Size (sqft)                       0.921747
# Year_Built                              0.250045
# Crime_Rate (per 1000 people)           -0.021909
# Distance_to_City_Center (miles)        -0.051750
# House_Price ($)                         1.000000

# %%
vdata = pd.DataFrame()
vdata["Feature"] = data.columns
vdata["VIF"] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1])]
print(vdata)
# Out:
#                            Feature        VIF
# 0                House_Size (sqft)  52.220235
# 1                       Year_Built  16.112541
# 2     Crime_Rate (per 1000 people)   5.081792
# 3  Distance_to_City_Center (miles)   4.753887
# 4                  House_Price ($)  56.362391

# %%
data["Age_of_House"]=2025-data["Year_Built"]
data.drop(columns=["Year_Built"], inplace=True)
data.head()
# Out:
#    House_Size (sqft)  Crime_Rate (per 1000 people)  \
# 0               1660                          9.50
# 1               4572                          3.70
# 2               3892                          7.39
# 3               1266                          5.62
# 4               4244                          1.08
#
#    Distance_to_City_Center (miles)  House_Price ($)  Age_of_House
# 0                            46.69         370810.0            22
# 1                            22.24         648460.0            75
# 2                            49.03         749600.0            32
# 3                            25.86         167180.0            31
# 4                             6.16         721200.0            29

# %%
x=data.drop(columns="House_Price ($)")
y=data["House_Price ($)"]/100000
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2, random_state=42)

# %%
b=data.corr()
print(b)
# Out:
#                                  House_Size (sqft)  \
# House_Size (sqft)                         1.000000
# Crime_Rate (per 1000 people)              0.045773
# Distance_to_City_Center (miles)           0.018404
# House_Price ($)                           0.921747
# Age_of_House                             -0.041368
#
#                                  Crime_Rate (per 1000 people)  \
# House_Size (sqft)                                    0.045773
# Crime_Rate (per 1000 people)                         1.000000
# Distance_to_City_Center (miles)                      0.056652
# House_Price ($)                                     -0.021909
# Age_of_House                                         0.079472
#
#                                  Distance_to_City_Center (miles)  \
# House_Size (sqft)                                       0.018404
# Crime_Rate (per 1000 people)                            0.056652
# Distance_to_City_Center (miles)                         1.000000
# House_Price ($)                                        -0.051750
# Age_of_House                                           -0.035983
#
#                                  House_Price ($)  Age_of_House
# House_Size (sqft)                       0.921747     -0.041368
# Crime_Rate (per 1000 people)           -0.021909      0.079472
# Distance_to_City_Center (miles)        -0.051750     -0.035983
# House_Price ($)                         1.000000     -0.250045
# Age_of_House                           -0.250045      1.000000

# %%
vdata = pd.DataFrame()
vdata["Feature"] = data.columns
vdata["VIF"] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1])]
print(vdata)
# Out:
#                            Feature        VIF
# 0                House_Size (sqft)  60.102921
# 1     Crime_Rate (per 1000 people)   4.322419
# 2  Distance_to_City_Center (miles)   3.749857
# 3                  House_Price ($)  53.611144
# 4                     Age_of_House   4.020245

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pre=lr.predict(x_test)
ms=mean_squared_error(y_test, y_pre)
r= r2_score(y_test, y_pre)
print("ms=",ms)
print("r2=",r)
# Out:
# ms= 0.3903229704764081
# r2= 0.8966000931175009

# %%
scores = cross_val_score(lr, x, y, cv=5, scoring="r2")
print(f"Cross-Validation R² Scores: {scores}")
print(f"Average R²: {scores.mean()}")
# Out:
# Cross-Validation R² Scores: [0.90047778 0.86987492 0.92008678 0.91382154 0.89090695]
# Average R²: 0.8990335954296793

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(random_state=42)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print("MSE:", mean_squared_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# MSE: 0.9385467830000002
# R2 Score: 0.7513708971608303

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(x_train, y_train)
y_pred = rf_model.predict(x_test)

print("MSE:", mean_squared_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
#feature importances
importances = rf_model.feature_importances_
for feature, importance in zip(x.columns, importances):
    print(f"{feature}: {importance}")
# Out:
# MSE: 0.5063152824701104
# R2 Score: 0.8658727335552496
# House_Size (sqft): 0.8889821832262578
# Crime_Rate (per 1000 people): 0.0218756237123545
# Distance_to_City_Center (miles): 0.026339346406727072
# Age_of_House: 0.06280284665466071

# %%
residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.axhline(y=0, color="red", linestyle="--")
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs Predicted Prices")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]
}
grid_search = GridSearchCV(RandomForestRegressor(random_state=42), param_grid, cv=5)
grid_search.fit(x_train, y_train)

print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 200}

# %%
importances = model.feature_importances_
feature_names = x.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title("Feature Importance")
plt.show()
